# %% [markdown]
# # Import e tratamento dos dados

# %% [markdown]
# ## Import de dados

# %%
import pandas as pd

# %%
df_2016 = pd.read_csv("01_dados_originais/receita_2016.csv", sep=";")
df_2016
# Out:
#        Unnamed: 0                                        Número Guia  \
# 0             NaN                                    Poder Executivo
# 1             NaN   Instituição: Instituto de Previdência e Assis...
# 2             NaN                                                  1
# 3             NaN                                                  2
# 4             NaN                                                  3
# ...           ...                                                ...
# 12494         NaN                                                466
# 12495         NaN                                                467
# 12496         NaN                                                468
# 12497         NaN                                                469
# 12498         NaN                              Total: 103.399.046,97
#
#                                                  Receita        Data  \
# ...

# %%
df_instituto_previdencia_assistencia_social_2016 = pd.read_csv("02_dados_pre_tratados/dados_instituto_previdencia_assistencia_social_2016.csv", sep=";")
df_instituto_previdencia_assistencia_social_2016
# Out:
#       Número Guia                                            Receita  \
# 0               1  1325019900-Receita de Remuneração de Outros De...
# 1               2  1325019900-Receita de Remuneração de Outros De...
# 2               3  1210290703-Contribuição de Servidor Ativo Civi...
# 3               4  1210290702-Contribuição de Servidor Ativo Civi...
# 4               5  1210290702-Contribuição de Servidor Ativo Civi...
# ..            ...                                                ...
# 248           255  1325019900-Receita de Remuneração de Outros De...
# 249           256  1325019900-Receita de Remuneração de Outros De...
# 250           257  1325019900-Receita de Remuneração de Outros De...
# 251           258  7210290200-Contribuição Patronal - Câmara - In...
# 252           259  7210290200-Contribuição Patronal - Câmara - In...
#
#            Data                     Nome            CPF/CNPJ Valor Previsto  \
# ...

# %%
df_prefeitura_2016 = pd.read_csv("02_dados_pre_tratados/dados_prefeitura_2016.csv", sep=";")
df_prefeitura_2016
# Out:
#         Número Guia                                            Receita  \
# 0                 1  1721010200-Cota-Parte do Fundo de Participação...
# 1                 2  1721010200-Cota-Parte do Fundo de Participação...
# 2                 3  1721010200-Cota-Parte do Fundo de Participação...
# 3                 4  1721010200-Cota-Parte do Fundo de Participação...
# 4                 5  1721010200-Cota-Parte do Fundo de Participação...
# ...             ...                                                ...
# 11769         12933  9722010200-Dedução de Receita para a Formação ...
# 11770         12934      1722010400-Cota-Parte do IPI sobre Exportação
# 11771         12935  9722010400-Dedução de Receita para a Formação ...
# 11772         12936  1113050000-Imposto sobre Serviços de Qualquer ...
# 11773         12937  1230000000-Contribuição para o Custeio do Serv...
#
#              Data                                 Nome            CPF/CNPJ  \
# ...

# %%
df_sctrans_2016 = pd.read_csv("02_dados_pre_tratados/dados_sctrans_2016.csv", sep=";")
df_sctrans_2016
# Out:
#       Número Guia                                            Receita  \
# 0               1  1919150000-Multas Previstas na Legislação de T...
# 1               2  1919150000-Multas Previstas na Legislação de T...
# 2               3  1919150000-Multas Previstas na Legislação de T...
# 3               4  1121300000-Taxa de Autorização de Funcionament...
# 4               5  1121300000-Taxa de Autorização de Funcionament...
# ..            ...                                                ...
# 460           464  1919150000-Multas Previstas na Legislação de T...
# 461           466  1919150000-Multas Previstas na Legislação de T...
# 462           467  1919150000-Multas Previstas na Legislação de T...
# 463           468                     1922990000-Outras Restituições
# 464           469  1325029900-Remuneração de Outros Depósitos de ...
#
#            Data                           Nome            CPF/CNPJ  \
# 0    04/01/2016            BANCO DO BRASIL S/A  00.000.000/0099-03
# ...

# %% [markdown]
# ## Tratamento dos DataFrames

# %%
# Definindo tipos das colunas antes de ler o dataset
columns_types = {'Receita': str, 'Data': str}

# %%
columns_Titles = [' Número Guia', 'Código', 'Receita', 'Data', 'Nome', 'CPF/CNPJ', 'Valor Previsto', 'Valor Lançado', 'Valor Arrecadado']

# %%
def tratar_valores(valor):
#     print(f'Tamanho da string com pontuação: {len(valor)}')
    posicao_virgula = valor.find(',')
    posicao_ponto = valor.find('.')
#     print(f'Posição da vírgula: {posicao_virgula}')
#     print(f'Posição do ponto: {posicao_ponto}')
    
    string = ''.join(filter(str.isalnum, valor))
#     print(f'Tamanho da string sem pontuação: {len(string)}')
#     print(string)
    nova_posicao_ponto = posicao_virgula - (len(valor) - len(string))

    if len(string) == len(valor):
        return valor
    
    elif posicao_ponto != -1:        
        string = string[0:nova_posicao_ponto+1] + '.' + string[nova_posicao_ponto+1:]
        if valor[0] == '-':
            string = '-' + string
            return string
        return string
    
    else:
        if valor[0] == '-':
            string = string[0:posicao_virgula-1] + '.' + string[posicao_virgula-1:]       
            string = '-' + string
            return string
        
        string = string[0:posicao_virgula] + '.' + string[posicao_virgula:]        
        return string
    
    '''
        Função para separar a string que carregava o valor do código e da descrição do que cada um significava
    '''    
def tratar_df(df, column, new_column):
    '''
        Há um padrão nas strings. O código numérico vai até a possição 11, o restante é o separador, hífen, que não foi armazeando,
        e a descrição que fora armazenada na nova coluna.    
    '''
    df[new_column] = df[column].str.slice(0,10)
    df[column] = df[column].str.slice(11,)

# %% [markdown]
# ### Tratando dados

# %%
tratar_df(df_instituto_previdencia_assistencia_social_2016, 'Receita', 'Código')
df_instituto_previdencia_assistencia_social_2016 = df_instituto_previdencia_assistencia_social_2016.reindex(columns=columns_Titles)
df_instituto_previdencia_assistencia_social_2016['Valor Previsto'] = df_instituto_previdencia_assistencia_social_2016['Valor Previsto'].apply(tratar_valores)
df_instituto_previdencia_assistencia_social_2016['Valor Arrecadado'] = df_instituto_previdencia_assistencia_social_2016['Valor Arrecadado'].apply(tratar_valores)
df_instituto_previdencia_assistencia_social_2016
# Out:
#       Número Guia      Código  \
# 0               1  1325019900
# 1               2  1325019900
# 2               3  1210290703
# 3               4  1210290702
# 4               5  1210290702
# ..            ...         ...
# 248           255  1325019900
# 249           256  1325019900
# 250           257  1325019900
# 251           258  7210290200
# 252           259  7210290200
#
#                                                Receita        Data  \
# 0    Receita de Remuneração de Outros Depósitos Ban...  31/01/2016
# 1    Receita de Remuneração de Outros Depósitos Ban...  31/01/2016
# 2       Contribuição de Servidor Ativo Civil - SCTRANS  08/01/2016
# 3    Contribuição de Servidor Ativo Civil - Prefeitura  11/01/2016
# 4    Contribuição de Servidor Ativo Civil - Prefeitura  19/01/2016
# ..                                                 ...         ...
# 248  Receita de Remuneração de Outros Depósitos Ban...  30/12/2016
# ...

# %%
tratar_df(df_prefeitura_2016, 'Receita', 'Código')
df_prefeitura_2016 = df_prefeitura_2016.reindex(columns=columns_Titles)
df_prefeitura_2016['Valor Previsto'] = df_prefeitura_2016['Valor Previsto'].apply(tratar_valores)
df_prefeitura_2016['Valor Arrecadado'] = df_prefeitura_2016['Valor Arrecadado'].apply(tratar_valores)
df_prefeitura_2016
# Out:
#         Número Guia      Código  \
# 0                 1  1721010200
# 1                 2  1721010200
# 2                 3  1721010200
# 3                 4  1721010200
# 4                 5  1721010200
# ...             ...         ...
# 11769         12933  9722010200
# 11770         12934  1722010400
# 11771         12935  9722010400
# 11772         12936  1113050000
# 11773         12937  1230000000
#
#                                                  Receita        Data  \
# 0      Cota-Parte do Fundo de Participação dos Municí...  07/01/2016
# 1      Cota-Parte do Fundo de Participação dos Municí...  07/01/2016
# 2      Cota-Parte do Fundo de Participação dos Municí...  08/01/2016
# 3      Cota-Parte do Fundo de Participação dos Municí...  08/01/2016
# 4      Cota-Parte do Fundo de Participação dos Municí...  20/01/2016
# ...                                                  ...         ...
# 11769  Dedução de Receita para a Formação do FUNDEB -...  30/12/2016
# ...

# %%
tratar_df(df_sctrans_2016, 'Receita', 'Código')
df_sctrans_2016 = df_sctrans_2016.reindex(columns=columns_Titles)
df_sctrans_2016['Valor Previsto'] = df_sctrans_2016['Valor Previsto'].apply(tratar_valores)
df_sctrans_2016['Valor Arrecadado'] = df_sctrans_2016['Valor Arrecadado'].apply(tratar_valores)
df_sctrans_2016
# Out:
#       Número Guia      Código  \
# 0               1  1919150000
# 1               2  1919150000
# 2               3  1919150000
# 3               4  1121300000
# 4               5  1121300000
# ..            ...         ...
# 460           464  1919150000
# 461           466  1919150000
# 462           467  1919150000
# 463           468  1922990000
# 464           469  1325029900
#
#                                                Receita        Data  \
# 0           Multas Previstas na Legislação de Trânsito  04/01/2016
# 1           Multas Previstas na Legislação de Trânsito  05/01/2016
# 2           Multas Previstas na Legislação de Trânsito  05/01/2016
# 3    Taxa de Autorização de Funcionamento de Transp...  05/01/2016
# 4    Taxa de Autorização de Funcionamento de Transp...  06/01/2016
# ..                                                 ...         ...
# 460         Multas Previstas na Legislação de Trânsito  28/12/2016
# ...

# %% [markdown]
# ## Salvando dados tratados

# %%
df_instituto_previdencia_assistencia_social_2016.to_csv('03_dados_tratados/dados_assistencia_social_tratados_2016.csv', index=False, sep=';')
df_prefeitura_2016.to_csv('03_dados_tratados/dados_prefeitura_tratados_2016.csv', index=False, sep=';')
df_sctrans_2016.to_csv('03_dados_tratados/dados_sctrans_tratados_2016.csv.csv', index=False, sep=';')

# %% [markdown]
# ## Juntando todos os dados tratados em um único documento

# %%
df_prefeitura_2016['Tipo'] = 1
df_instituto_previdencia_assistencia_social_2016['Tipo'] = 2
df_sctrans_2016['Tipo'] = 3

# %%
df_dados_acumulados_2016 = pd.merge(df_prefeitura_2016, df_instituto_previdencia_assistencia_social_2016, how='outer')
df_dados_acumulados_2016 = pd.merge(df_dados_acumulados_2016, df_sctrans_2016, how='outer')
df_dados_acumulados_2016
# Out:
#         Número Guia      Código  \
# 0                 1  1721010200
# 1                 2  1721010200
# 2                 3  1721010200
# 3                 4  1721010200
# 4                 5  1721010200
# ...             ...         ...
# 12487           464  1919150000
# 12488           466  1919150000
# 12489           467  1919150000
# 12490           468  1922990000
# 12491           469  1325029900
#
#                                                  Receita        Data  \
# 0      Cota-Parte do Fundo de Participação dos Municí...  07/01/2016
# 1      Cota-Parte do Fundo de Participação dos Municí...  07/01/2016
# 2      Cota-Parte do Fundo de Participação dos Municí...  08/01/2016
# 3      Cota-Parte do Fundo de Participação dos Municí...  08/01/2016
# 4      Cota-Parte do Fundo de Participação dos Municí...  20/01/2016
# ...                                                  ...         ...
# 12487         Multas Previstas na Legislação de Trânsito  28/12/2016
# ...

# %%
df_dados_acumulados_2016.drop(' Número Guia',axis=1, inplace=True)
df_dados_acumulados_2016.drop('Valor Lançado',axis=1, inplace=True)
df_dados_acumulados_2016
# Out:
#            Código                                            Receita  \
# 0      1721010200  Cota-Parte do Fundo de Participação dos Municí...
# 1      1721010200  Cota-Parte do Fundo de Participação dos Municí...
# 2      1721010200  Cota-Parte do Fundo de Participação dos Municí...
# 3      1721010200  Cota-Parte do Fundo de Participação dos Municí...
# 4      1721010200  Cota-Parte do Fundo de Participação dos Municí...
# ...           ...                                                ...
# 12487  1919150000         Multas Previstas na Legislação de Trânsito
# 12488  1919150000         Multas Previstas na Legislação de Trânsito
# 12489  1919150000         Multas Previstas na Legislação de Trânsito
# 12490  1922990000                                Outras Restituições
# 12491  1325029900  Remuneração de Outros Depósitos de Recursos nã...
#
#              Data                           Nome            CPF/CNPJ  \
# ...

# %%
df_dados_acumulados_2016.to_csv('04_analise_tratamento_carga/dados_acumulados_2016.csv', index=False, sep=';')
