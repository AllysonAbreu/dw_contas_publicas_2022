# %% [markdown]
# # Import e tratamento dos dados

# %% [markdown]
# ## Import de dados

# %%
import pandas as pd

# %%
df_2019 = pd.read_csv("01_dados_originais/receita_2019.csv", sep=";")
df_2019
# Out:
#        Unnamed: 0                                        Número Guia  \
# 0             NaN                                    Poder Executivo
# 1             NaN   Instituição: Instituto de Previdência e Assis...
# 2             NaN                                                  1
# 3             NaN                                                  2
# 4             NaN                                                  3
# ...           ...                                                ...
# 10997         NaN                                                513
# 10998         NaN                                                515
# 10999         NaN                                                516
# 11000         NaN                                                517
# 11001         NaN                              Total: 136.691.710,71
#
#                                                  Receita        Data  \
# ...

# %%
df_instituto_previdencia_assistencia_social_2019 = pd.read_csv("02_dados_pre_tratados/dados_instituto_previdencia_assistencia_social_2019.csv", sep=";")
df_instituto_previdencia_assistencia_social_2019
# Out:
#       Número Guia                                            Receita  \
# 0               1  1218011102-Contribuição de Servidor Ativo Civi...
# 1               2  7218041101-CPSSS Patronal - Parcelamentos - Se...
# 2               3  1990031100-Compensações Financeiras entre o Re...
# 3               4    1219991100-Demais Contribuições Previdenciárias
# 4               5  1218011101-Contribuição de Servidor Ativo Civi...
# ..            ...                                                ...
# 329           362  7218041101-CPSSS Patronal - Parcelamentos - Se...
# 330           363  7218041101-CPSSS Patronal - Parcelamentos - Se...
# 331           364  7218041101-CPSSS Patronal - Parcelamentos - Se...
# 332           365  1321004100-Remuneração dos Recursos do Regime ...
# 333           366  1321004100-Remuneração dos Recursos do Regime ...
#
#            Data                                               Nome  \
# 0    02/01/2019                                            SCTRANS
# ...

# %%
df_prefeitura_2019 = pd.read_csv("02_dados_pre_tratados/dados_prefeitura_2019.csv", sep=";")
df_prefeitura_2019
# Out:
#         Número Guia                                            Receita  \
# 0                 1  1718032101-Serviços de Atendimento Móvel as Ur...
# 1                 2  1718031100-Piso de Atenção Básica Fixo - PAB Fixo
# 2                 3  1118023100-Imposto sobre Serviços de Qualquer ...
# 3                 4  1118023100-Imposto sobre Serviços de Qualquer ...
# 4                 5  1118023100-Imposto sobre Serviços de Qualquer ...
# ...             ...                                                ...
# 10144         10500  9728012100-Dedução da Receita do IPVA - FUNDEB...
# 10145         10501  9728013100-Dedução da Receita do IPI - FUNDEB ...
# 10146         10502                1718121108-Outros Programas do FNAS
# 10147         10503                1718121108-Outros Programas do FNAS
# 10148         10504  1321001103-Remuneração de Outros Depósitos de ...
#
#              Data                     Nome            CPF/CNPJ Valor Previsto  \
# ...

# %%
df_sctrans_2019 = pd.read_csv("02_dados_pre_tratados/dados_sctrans_2019.csv", sep=";")
df_sctrans_2019
# Out:
#       Número Guia                                            Receita  \
# 0               1  1910011100-Multas Previstas em Legislação de T...
# 1               2  1121011102-Taxa de Autorização de Funcionament...
# 2               3  1910011100-Multas Previstas em Legislação de T...
# 3               4  1121011102-Taxa de Autorização de Funcionament...
# 4               5  1910011100-Multas Previstas em Legislação de T...
# ..            ...                                                ...
# 507           512  1910011100-Multas Previstas em Legislação de T...
# 508           513  1910011100-Multas Previstas em Legislação de T...
# 509           515  1321001103-Remuneração de Outros Depósitos de ...
# 510           516  1910011100-Multas Previstas em Legislação de T...
# 511           517                         1990991100-Outras Receitas
#
#            Data                 Nome            CPF/CNPJ Valor Previsto  \
# ...

# %% [markdown]
# ## Tratamento dos DataFrames

# %%
# Definindo tipos das colunas antes de ler o dataset
columns_types = {'Receita': str, 'Data': str}

# %%
columns_Titles = [' Número Guia', 'Código', 'Receita', 'Data', 'Nome', 'CPF/CNPJ', 'Valor Previsto', 'Valor Lançado', 'Valor Arrecadado']

# %%
def tratar_valores(valor):
#     print(f'Tamanho da string com pontuação: {len(valor)}')
    posicao_virgula = valor.find(',')
    posicao_ponto = valor.find('.')
#     print(f'Posição da vírgula: {posicao_virgula}')
#     print(f'Posição do ponto: {posicao_ponto}')
    
    string = ''.join(filter(str.isalnum, valor))
#     print(f'Tamanho da string sem pontuação: {len(string)}')
#     print(string)
    nova_posicao_ponto = posicao_virgula - (len(valor) - len(string))

    if len(string) == len(valor):
        return valor
    
    elif posicao_ponto != -1:        
        string = string[0:nova_posicao_ponto+1] + '.' + string[nova_posicao_ponto+1:]
        if valor[0] == '-':
            string = '-' + string
            return string
        return string
    
    else:
        if valor[0] == '-':
            string = string[0:posicao_virgula-1] + '.' + string[posicao_virgula-1:]       
            string = '-' + string
            return string
        
        string = string[0:posicao_virgula] + '.' + string[posicao_virgula:]        
        return string
    
    '''
        Função para separar a string que carregava o valor do código e da descrição do que cada um significava
    '''    
def tratar_df(df, column, new_column):
    '''
        Há um padrão nas strings. O código numérico vai até a possição 11, o restante é o separador, hífen, que não foi armazeando,
        e a descrição que fora armazenada na nova coluna.    
    '''
    df[new_column] = df[column].str.slice(0,10)
    df[column] = df[column].str.slice(11,)

# %% [markdown]
# ### Tratando dados

# %%
tratar_df(df_instituto_previdencia_assistencia_social_2019, 'Receita', 'Código')
df_instituto_previdencia_assistencia_social_2019 = df_instituto_previdencia_assistencia_social_2019.reindex(columns=columns_Titles)
df_instituto_previdencia_assistencia_social_2019['Valor Previsto'] = df_instituto_previdencia_assistencia_social_2019['Valor Previsto'].apply(tratar_valores)
df_instituto_previdencia_assistencia_social_2019['Valor Arrecadado'] = df_instituto_previdencia_assistencia_social_2019['Valor Arrecadado'].apply(tratar_valores)
df_instituto_previdencia_assistencia_social_2019
# Out:
#       Número Guia      Código  \
# 0               1  1218011102
# 1               2  7218041101
# 2               3  1990031100
# 3               4  1219991100
# 4               5  1218011101
# ..            ...         ...
# 329           362  7218041101
# 330           363  7218041101
# 331           364  7218041101
# 332           365  1321004100
# 333           366  1321004100
#
#                                                Receita        Data  \
# 0       Contribuição de Servidor Ativo Civil - SCTRANS  02/01/2019
# 1    CPSSS Patronal - Parcelamentos - Servidor Civi...  02/01/2019
# 2    Compensações Financeiras entre o Regime Geral ...  08/01/2019
# 3                 Demais Contribuições Previdenciárias  10/01/2019
# 4    Contribuição de Servidor Ativo Civil - Prefeitura  10/01/2019
# ..                                                 ...         ...
# 329  CPSSS Patronal - Parcelamentos - Servidor Civi...  30/12/2019
# ...

# %%
tratar_df(df_prefeitura_2019, 'Receita', 'Código')
df_prefeitura_2019 = df_prefeitura_2019.reindex(columns=columns_Titles)
df_prefeitura_2019['Valor Previsto'] = df_prefeitura_2019['Valor Previsto'].apply(tratar_valores)
df_prefeitura_2019['Valor Arrecadado'] = df_prefeitura_2019['Valor Arrecadado'].apply(tratar_valores)
df_prefeitura_2019
# Out:
#         Número Guia      Código  \
# 0                 1  1718032101
# 1                 2  1718031100
# 2                 3  1118023100
# 3                 4  1118023100
# 4                 5  1118023100
# ...             ...         ...
# 10144         10500  9728012100
# 10145         10501  9728013100
# 10146         10502  1718121108
# 10147         10503  1718121108
# 10148         10504  1321001103
#
#                                                  Receita        Data  \
# 0      Serviços de Atendimento Móvel as Urgências - S...  02/01/2019
# 1                 Piso de Atenção Básica Fixo - PAB Fixo  07/01/2019
# 2      Imposto sobre Serviços de Qualquer Natureza  ISS  02/01/2019
# 3      Imposto sobre Serviços de Qualquer Natureza  ISS  02/01/2019
# 4      Imposto sobre Serviços de Qualquer Natureza  ISS  02/01/2019
# ...                                                  ...         ...
# 10144  Dedução da Receita do IPVA - FUNDEB e Redutor ...  31/12/2019
# ...

# %%
tratar_df(df_sctrans_2019, 'Receita', 'Código')
df_sctrans_2019 = df_sctrans_2019.reindex(columns=columns_Titles)
df_sctrans_2019['Valor Previsto'] = df_sctrans_2019['Valor Previsto'].apply(tratar_valores)
df_sctrans_2019['Valor Arrecadado'] = df_sctrans_2019['Valor Arrecadado'].apply(tratar_valores)
df_sctrans_2019
# Out:
#       Número Guia      Código  \
# 0               1  1910011100
# 1               2  1121011102
# 2               3  1910011100
# 3               4  1121011102
# 4               5  1910011100
# ..            ...         ...
# 507           512  1910011100
# 508           513  1910011100
# 509           515  1321001103
# 510           516  1910011100
# 511           517  1990991100
#
#                                                Receita        Data  \
# 0           Multas Previstas em Legislação de Trânsito  02/01/2019
# 1    Taxa de Autorização de Funcionamento de Transp...  02/01/2019
# 2           Multas Previstas em Legislação de Trânsito  03/01/2019
# 3    Taxa de Autorização de Funcionamento de Transp...  04/01/2019
# 4           Multas Previstas em Legislação de Trânsito  07/01/2019
# ..                                                 ...         ...
# 507         Multas Previstas em Legislação de Trânsito  26/12/2019
# ...

# %% [markdown]
# ## Salvando dados tratados

# %%
df_instituto_previdencia_assistencia_social_2019.to_csv('03_dados_tratados/dados_assistencia_social_tratados_2019.csv', index=False, sep=';')
df_prefeitura_2019.to_csv('03_dados_tratados/dados_prefeitura_tratados_2019.csv', index=False, sep=';')
df_sctrans_2019.to_csv('03_dados_tratados/dados_sctrans_tratados_2019.csv.csv', index=False, sep=';')

# %% [markdown]
# ## Juntando todos os dados tratados em um único documento

# %%
df_prefeitura_2019['Tipo'] = 1
df_instituto_previdencia_assistencia_social_2019['Tipo'] = 2
df_sctrans_2019['Tipo'] = 3

# %%
df_prefeitura_2019.drop('Valor Lançado',axis=1, inplace=True)
df_instituto_previdencia_assistencia_social_2019.drop('Valor Lançado',axis=1, inplace=True)
df_sctrans_2019.drop('Valor Lançado',axis=1, inplace=True)

# %%
df_dados_acumulados_2019 = pd.merge(df_prefeitura_2019, df_instituto_previdencia_assistencia_social_2019, how='outer')
df_dados_acumulados_2019 = pd.merge(df_dados_acumulados_2019, df_sctrans_2019, how='outer')
df_dados_acumulados_2019
# Out:
#         Número Guia      Código  \
# 0                 1  1718032101
# 1                 2  1718031100
# 2                 3  1118023100
# 3                 4  1118023100
# 4                 5  1118023100
# ...             ...         ...
# 10990           512  1910011100
# 10991           513  1910011100
# 10992           515  1321001103
# 10993           516  1910011100
# 10994           517  1990991100
#
#                                                  Receita        Data  \
# 0      Serviços de Atendimento Móvel as Urgências - S...  02/01/2019
# 1                 Piso de Atenção Básica Fixo - PAB Fixo  07/01/2019
# 2      Imposto sobre Serviços de Qualquer Natureza  ISS  02/01/2019
# 3      Imposto sobre Serviços de Qualquer Natureza  ISS  02/01/2019
# 4      Imposto sobre Serviços de Qualquer Natureza  ISS  02/01/2019
# ...                                                  ...         ...
# 10990         Multas Previstas em Legislação de Trânsito  26/12/2019
# ...

# %%
df_dados_acumulados_2019.drop(' Número Guia',axis=1, inplace=True)
df_dados_acumulados_2019
# Out:
#            Código                                            Receita  \
# 0      1718032101  Serviços de Atendimento Móvel as Urgências - S...
# 1      1718031100             Piso de Atenção Básica Fixo - PAB Fixo
# 2      1118023100  Imposto sobre Serviços de Qualquer Natureza  ISS
# 3      1118023100  Imposto sobre Serviços de Qualquer Natureza  ISS
# 4      1118023100  Imposto sobre Serviços de Qualquer Natureza  ISS
# ...           ...                                                ...
# 10990  1910011100         Multas Previstas em Legislação de Trânsito
# 10991  1910011100         Multas Previstas em Legislação de Trânsito
# 10992  1321001103  Remuneração de Outros Depósitos de Recursos nã...
# 10993  1910011100         Multas Previstas em Legislação de Trânsito
# 10994  1990991100                                    Outras Receitas
#
#              Data                     Nome            CPF/CNPJ Valor Previsto  \
# ...

# %%
df_dados_acumulados_2019.to_csv('04_analise_tratamento_carga/dados_acumulados_2019.csv', index=False, sep=';')
