# %% [markdown]
# # Import e tratamento dos dados

# %% [markdown]
# ## Import de dados

# %%
import pandas as pd

# %%
df_2018 = pd.read_csv("01_dados_originais/receita_2018.csv", sep=";")
df_2018
# Out:
#        Unnamed: 0                                        Número Guia  \
# 0             NaN                                    Poder Executivo
# 1             NaN   Instituição: Instituto de Previdência e Assis...
# 2             NaN                                                  2
# 3             NaN                                                  3
# 4             NaN                                                  4
# ...           ...                                                ...
# 10916         NaN                                                500
# 10917         NaN                                                501
# 10918         NaN                                                502
# 10919         NaN                                                503
# 10920         NaN                              Total: 125.478.351,59
#
#                                                  Receita        Data  \
# ...

# %%
df_instituto_previdencia_assistencia_social_2018 = pd.read_csv("02_dados_pre_tratados/dados_instituto_previdencia_assistencia_social_2018.csv", sep=";")
df_instituto_previdencia_assistencia_social_2018
# Out:
#       Número Guia                                            Receita  \
# 0               2  1210290702-Contribuição de Servidor Ativo Civi...
# 1               3  1922100000-Compensações Financ.entre o Reg.Ger...
# 2               4  1210290703-Contribuição de Servidor Ativo Civi...
# 3               5  1210290703-Contribuição de Servidor Ativo Civi...
# 4               6  1210290701-Contribuição de Servidor Ativo Civi...
# ..            ...                                                ...
# 363           511    1210299900-Outras contribuições Previdênciárias
# 364           512  1328100000-Remuneração dos Investimentos do Re...
# 365           513  1328100000-Remuneração dos Investimentos do Re...
# 366           514  1328100000-Remuneração dos Investimentos do Re...
# 367           516    1210299900-Outras contribuições Previdênciárias
#
#            Data                                               Nome  \
# 0    03/01/2018                 PREFEITURA MUNICIPAL DE CAJAZEIRAS
# ...

# %%
df_prefeitura_2018 = pd.read_csv("02_dados_pre_tratados/dados_prefeitura_2018.csv", sep=";")
df_prefeitura_2018
# Out:
#         Número Guia                                            Receita  \
# 0                 1  1113050000-Imposto sobre Serviços de Qualquer ...
# 1                 2  1113050000-Imposto sobre Serviços de Qualquer ...
# 2                 3  1113050000-Imposto sobre Serviços de Qualquer ...
# 3                 4  1113050000-Imposto sobre Serviços de Qualquer ...
# 4                 5  1113050000-Imposto sobre Serviços de Qualquer ...
# ...             ...                                                ...
# 10050         10962  1721341000-Índice de Gestão Descentralizada - ...
# 10051         10963  1721341000-Índice de Gestão Descentralizada - ...
# 10052         10972  1112043100-Imposto de Renda Retido nas Fontes ...
# 10053         10973         1220990000-Outras Contribuições Econômicas
# 10054         10974         1220990000-Outras Contribuições Econômicas
#
#              Data                                    Nome            CPF/CNPJ  \
# ...

# %%
df_sctrans_2018 = pd.read_csv("02_dados_pre_tratados/dados_sctrans_2018.csv", sep=";")
df_sctrans_2018
# Out:
#       Número Guia                                            Receita  \
# 0               1  1919150000-Multas Previstas na Legislação de T...
# 1               2  1121300000-Taxa de Autorização de Funcionament...
# 2               3  1919150000-Multas Previstas na Legislação de T...
# 3               4  1121300000-Taxa de Autorização de Funcionament...
# 4               5  1919150000-Multas Previstas na Legislação de T...
# ..            ...                                                ...
# 486           499  1919150000-Multas Previstas na Legislação de T...
# 487           500  1121300000-Taxa de Autorização de Funcionament...
# 488           501  1919150000-Multas Previstas na Legislação de T...
# 489           502  1121300000-Taxa de Autorização de Funcionament...
# 490           503  1325029900-Remuneração de Outros Depósitos de ...
#
#            Data                 Nome            CPF/CNPJ Valor Previsto  \
# ...

# %% [markdown]
# ## Tratamento dos DataFrames

# %%
# Definindo tipos das colunas antes de ler o dataset
columns_types = {'Receita': str, 'Data': str}

# %%
columns_Titles = [' Número Guia', 'Código', 'Receita', 'Data', 'Nome', 'CPF/CNPJ', 'Valor Previsto', 'Valor Lançado', 'Valor Arrecadado']

# %%
def tratar_valores(valor):
#     print(f'Tamanho da string com pontuação: {len(valor)}')
    posicao_virgula = valor.find(',')
    posicao_ponto = valor.find('.')
#     print(f'Posição da vírgula: {posicao_virgula}')
#     print(f'Posição do ponto: {posicao_ponto}')
    
    string = ''.join(filter(str.isalnum, valor))
#     print(f'Tamanho da string sem pontuação: {len(string)}')
#     print(string)
    nova_posicao_ponto = posicao_virgula - (len(valor) - len(string))

    if len(string) == len(valor):
        return valor
    
    elif posicao_ponto != -1:        
        string = string[0:nova_posicao_ponto+1] + '.' + string[nova_posicao_ponto+1:]
        if valor[0] == '-':
            string = '-' + string
            return string
        return string
    
    else:
        if valor[0] == '-':
            string = string[0:posicao_virgula-1] + '.' + string[posicao_virgula-1:]       
            string = '-' + string
            return string
        
        string = string[0:posicao_virgula] + '.' + string[posicao_virgula:]        
        return string
    
    '''
        Função para separar a string que carregava o valor do código e da descrição do que cada um significava
    '''    
def tratar_df(df, column, new_column):
    '''
        Há um padrão nas strings. O código numérico vai até a possição 11, o restante é o separador, hífen, que não foi armazeando,
        e a descrição que fora armazenada na nova coluna.    
    '''
    df[new_column] = df[column].str.slice(0,10)
    df[column] = df[column].str.slice(11,)

# %% [markdown]
# ### Tratando dados

# %%
tratar_df(df_instituto_previdencia_assistencia_social_2018, 'Receita', 'Código')
df_instituto_previdencia_assistencia_social_2018 = df_instituto_previdencia_assistencia_social_2018.reindex(columns=columns_Titles)
df_instituto_previdencia_assistencia_social_2018['Valor Previsto'] = df_instituto_previdencia_assistencia_social_2018['Valor Previsto'].apply(tratar_valores)
df_instituto_previdencia_assistencia_social_2018['Valor Arrecadado'] = df_instituto_previdencia_assistencia_social_2018['Valor Arrecadado'].apply(tratar_valores)
df_instituto_previdencia_assistencia_social_2018
# Out:
#       Número Guia      Código  \
# 0               2  1210290702
# 1               3  1922100000
# 2               4  1210290703
# 3               5  1210290703
# 4               6  1210290701
# ..            ...         ...
# 363           511  1210299900
# 364           512  1328100000
# 365           513  1328100000
# 366           514  1328100000
# 367           516  1210299900
#
#                                                Receita        Data  \
# 0    Contribuição de Servidor Ativo Civil - Prefeitura  03/01/2018
# 1    Compensações Financ.entre o Reg.Geral e os Reg...  08/01/2018
# 2       Contribuição de Servidor Ativo Civil - SCTRANS  11/01/2018
# 3       Contribuição de Servidor Ativo Civil - SCTRANS  11/01/2018
# 4        Contribuição de Servidor Ativo Civil - Câmara  22/01/2018
# ..                                                 ...         ...
# 363               Outras contribuições Previdênciárias  28/12/2018
# ...

# %%
tratar_df(df_prefeitura_2018, 'Receita', 'Código')
df_prefeitura_2018 = df_prefeitura_2018.reindex(columns=columns_Titles)
df_prefeitura_2018['Valor Previsto'] = df_prefeitura_2018['Valor Previsto'].apply(tratar_valores)
df_prefeitura_2018['Valor Arrecadado'] = df_prefeitura_2018['Valor Arrecadado'].apply(tratar_valores)
df_prefeitura_2018
# Out:
#         Número Guia      Código  \
# 0                 1  1113050000
# 1                 2  1113050000
# 2                 3  1113050000
# 3                 4  1113050000
# 4                 5  1113050000
# ...             ...         ...
# 10050         10962  1721341000
# 10051         10963  1721341000
# 10052         10972  1112043100
# 10053         10973  1220990000
# 10054         10974  1220990000
#
#                                                  Receita        Data  \
# 0            Imposto sobre Serviços de Qualquer Natureza  02/01/2018
# 1            Imposto sobre Serviços de Qualquer Natureza  04/01/2018
# 2            Imposto sobre Serviços de Qualquer Natureza  05/01/2018
# 3            Imposto sobre Serviços de Qualquer Natureza  08/01/2018
# 4            Imposto sobre Serviços de Qualquer Natureza  09/01/2018
# ...                                                  ...         ...
# 10050          Índice de Gestão Descentralizada - IGDPBF  31/12/2018
# ...

# %%
tratar_df(df_sctrans_2018, 'Receita', 'Código')
df_sctrans_2018 = df_sctrans_2018.reindex(columns=columns_Titles)
df_sctrans_2018['Valor Previsto'] = df_sctrans_2018['Valor Previsto'].apply(tratar_valores)
df_sctrans_2018['Valor Arrecadado'] = df_sctrans_2018['Valor Arrecadado'].apply(tratar_valores)
df_sctrans_2018
# Out:
#       Número Guia      Código  \
# 0               1  1919150000
# 1               2  1121300000
# 2               3  1919150000
# 3               4  1121300000
# 4               5  1919150000
# ..            ...         ...
# 486           499  1919150000
# 487           500  1121300000
# 488           501  1919150000
# 489           502  1121300000
# 490           503  1325029900
#
#                                                Receita        Data  \
# 0           Multas Previstas na Legislação de Trânsito  02/01/2018
# 1    Taxa de Autorização de Funcionamento de Transp...  02/01/2018
# 2           Multas Previstas na Legislação de Trânsito  03/01/2018
# 3    Taxa de Autorização de Funcionamento de Transp...  04/01/2018
# 4           Multas Previstas na Legislação de Trânsito  05/01/2018
# ..                                                 ...         ...
# 486         Multas Previstas na Legislação de Trânsito  27/12/2018
# ...

# %% [markdown]
# ## Salvando dados tratados

# %%
df_instituto_previdencia_assistencia_social_2018.to_csv('03_dados_tratados/dados_assistencia_social_tratados_2018.csv', index=False, sep=';')
df_prefeitura_2018.to_csv('03_dados_tratados/dados_prefeitura_tratados_2018.csv', index=False, sep=';')
df_sctrans_2018.to_csv('03_dados_tratados/dados_sctrans_tratados_2018.csv.csv', index=False, sep=';')

# %% [markdown]
# ## Juntando todos os dados tratados em um único documento

# %%
df_prefeitura_2018['Tipo'] = 1
df_instituto_previdencia_assistencia_social_2018['Tipo'] = 2
df_sctrans_2018['Tipo'] = 3

# %%
df_prefeitura_2018.drop('Valor Lançado',axis=1, inplace=True)
df_instituto_previdencia_assistencia_social_2018.drop('Valor Lançado',axis=1, inplace=True)
df_sctrans_2018.drop('Valor Lançado',axis=1, inplace=True)

# %%
df_dados_acumulados_2018 = pd.merge(df_prefeitura_2018, df_instituto_previdencia_assistencia_social_2018, how='outer')
df_dados_acumulados_2018 = pd.merge(df_dados_acumulados_2018, df_sctrans_2018, how='outer')
df_dados_acumulados_2018
# Out:
#         Número Guia      Código  \
# 0                 1  1113050000
# 1                 2  1113050000
# 2                 3  1113050000
# 3                 4  1113050000
# 4                 5  1113050000
# ...             ...         ...
# 10909           499  1919150000
# 10910           500  1121300000
# 10911           501  1919150000
# 10912           502  1121300000
# 10913           503  1325029900
#
#                                                  Receita        Data  \
# 0            Imposto sobre Serviços de Qualquer Natureza  02/01/2018
# 1            Imposto sobre Serviços de Qualquer Natureza  04/01/2018
# 2            Imposto sobre Serviços de Qualquer Natureza  05/01/2018
# 3            Imposto sobre Serviços de Qualquer Natureza  08/01/2018
# 4            Imposto sobre Serviços de Qualquer Natureza  09/01/2018
# ...                                                  ...         ...
# 10909         Multas Previstas na Legislação de Trânsito  27/12/2018
# ...

# %%
df_dados_acumulados_2018.drop(' Número Guia',axis=1, inplace=True)
df_dados_acumulados_2018
# Out:
#            Código                                            Receita  \
# 0      1113050000        Imposto sobre Serviços de Qualquer Natureza
# 1      1113050000        Imposto sobre Serviços de Qualquer Natureza
# 2      1113050000        Imposto sobre Serviços de Qualquer Natureza
# 3      1113050000        Imposto sobre Serviços de Qualquer Natureza
# 4      1113050000        Imposto sobre Serviços de Qualquer Natureza
# ...           ...                                                ...
# 10909  1919150000         Multas Previstas na Legislação de Trânsito
# 10910  1121300000  Taxa de Autorização de Funcionamento de Transp...
# 10911  1919150000         Multas Previstas na Legislação de Trânsito
# 10912  1121300000  Taxa de Autorização de Funcionamento de Transp...
# 10913  1325029900  Remuneração de Outros Depósitos de Recursos nã...
#
#              Data                  Nome            CPF/CNPJ Valor Previsto  \
# ...

# %%
df_dados_acumulados_2018.to_csv('04_analise_tratamento_carga/dados_acumulados_2018.csv', index=False, sep=';')
