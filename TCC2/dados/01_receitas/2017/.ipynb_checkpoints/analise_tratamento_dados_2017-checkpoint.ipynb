# %% [markdown]
# # Import e tratamento dos dados

# %% [markdown]
# ## Import de dados

# %%
import pandas as pd

# %%
df_2017 = pd.read_csv("01_dados_originais/receita_2017.csv", sep=";")
df_2017
# Out:
#        Unnamed: 0                                        Número Guia  \
# 0             NaN                                    Poder Executivo
# 1             NaN   Instituição: Instituto de Previdência e Assis...
# 2             NaN                                                  1
# 3             NaN                                                  2
# 4             NaN                                                  3
# ...           ...                                                ...
# 10194         NaN                                                480
# 10195         NaN                                                481
# 10196         NaN                                                482
# 10197         NaN                                                483
# 10198         NaN                              Total: 106.984.027,31
#
#                                                  Receita        Data  \
# ...

# %%
df_instituto_previdencia_assistencia_social_2017 = pd.read_csv("02_dados_pre_tratados/dados_instituto_previdencia_assistencia_social_2017.csv", sep=";")
df_instituto_previdencia_assistencia_social_2017
# Out:
#       Número Guia                                            Receita  \
# 0               1  1210290702-Contribuição de Servidor Ativo Civi...
# 1               2  1210290702-Contribuição de Servidor Ativo Civi...
# 2               3  1210290701-Contribuição de Servidor Ativo Civi...
# 3               4  7210290200-Contribuição Patronal - Câmara - In...
# 4               5  7210290200-Contribuição Patronal - Câmara - In...
# ..            ...                                                ...
# 263           323  1328100000-Remuneração dos Investimentos do Re...
# 264           324  1328100000-Remuneração dos Investimentos do Re...
# 265           325  1328100000-Remuneração dos Investimentos do Re...
# 266           326  1328100000-Remuneração dos Investimentos do Re...
# 267           327  1328100000-Remuneração dos Investimentos do Re...
#
#            Data                                Nome            CPF/CNPJ  \
# ...

# %%
df_prefeitura_2017 = pd.read_csv("02_dados_pre_tratados/dados_prefeitura_2017.csv", sep=";")
df_prefeitura_2017
# Out:
#        Número Guia                                            Receita  \
# 0                1  1113050000-Imposto sobre Serviços de Qualquer ...
# 1                2  1113050000-Imposto sobre Serviços de Qualquer ...
# 2                3  1113050000-Imposto sobre Serviços de Qualquer ...
# 3                4  1113050000-Imposto sobre Serviços de Qualquer ...
# 4                5                      1722010100-Cota-Parte do ICMS
# ...            ...                                                ...
# 9442         27571  1112043100-Imposto de Renda Retido nas Fontes ...
# 9443         27572  1112043100-Imposto de Renda Retido nas Fontes ...
# 9444         27573  1112043100-Imposto de Renda Retido nas Fontes ...
# 9445         27574  1112043100-Imposto de Renda Retido nas Fontes ...
# 9446         27575  1112043100-Imposto de Renda Retido nas Fontes ...
#
#             Data                  Nome            CPF/CNPJ Valor Previsto  \
# ...

# %%
df_sctrans_2017 = pd.read_csv("02_dados_pre_tratados/dados_sctrans_2017.csv", sep=";")
df_sctrans_2017
# Out:
#       Número Guia                                            Receita  \
# 0               1  1919150000-Multas Previstas na Legislação de T...
# 1               2  1919150000-Multas Previstas na Legislação de T...
# 2               3  1919150000-Multas Previstas na Legislação de T...
# 3               4  1919150000-Multas Previstas na Legislação de T...
# 4               5  1919150000-Multas Previstas na Legislação de T...
# ..            ...                                                ...
# 472           479  1919150000-Multas Previstas na Legislação de T...
# 473           480  1121300000-Taxa de Autorização de Funcionament...
# 474           481  1919150000-Multas Previstas na Legislação de T...
# 475           482  1121300000-Taxa de Autorização de Funcionament...
# 476           483  1325029900-Remuneração de Outros Depósitos de ...
#
#            Data                 Nome            CPF/CNPJ Valor Previsto  \
# ...

# %% [markdown]
# ## Tratamento dos DataFrames

# %%
# Definindo tipos das colunas antes de ler o dataset
columns_types = {'Receita': str, 'Data': str}

# %%
columns_Titles = [' Número Guia', 'Código', 'Receita', 'Data', 'Nome', 'CPF/CNPJ', 'Valor Previsto', 'Valor Lançado', 'Valor Arrecadado']

# %%
def tratar_valores(valor):
#     print(f'Tamanho da string com pontuação: {len(valor)}')
    posicao_virgula = valor.find(',')
    posicao_ponto = valor.find('.')
#     print(f'Posição da vírgula: {posicao_virgula}')
#     print(f'Posição do ponto: {posicao_ponto}')
    
    string = ''.join(filter(str.isalnum, valor))
#     print(f'Tamanho da string sem pontuação: {len(string)}')
#     print(string)
    nova_posicao_ponto = posicao_virgula - (len(valor) - len(string))

    if len(string) == len(valor):
        return valor
    
    elif posicao_ponto != -1:        
        string = string[0:nova_posicao_ponto+1] + '.' + string[nova_posicao_ponto+1:]
        if valor[0] == '-':
            string = '-' + string
            return string
        return string
    
    else:
        if valor[0] == '-':
            string = string[0:posicao_virgula-1] + '.' + string[posicao_virgula-1:]       
            string = '-' + string
            return string
        
        string = string[0:posicao_virgula] + '.' + string[posicao_virgula:]        
        return string
    
    '''
        Função para separar a string que carregava o valor do código e da descrição do que cada um significava
    '''    
def tratar_df(df, column, new_column):
    '''
        Há um padrão nas strings. O código numérico vai até a possição 11, o restante é o separador, hífen, que não foi armazeando,
        e a descrição que fora armazenada na nova coluna.    
    '''
    df[new_column] = df[column].str.slice(0,10)
    df[column] = df[column].str.slice(11,)

# %% [markdown]
# ### Tratando dados

# %%
tratar_df(df_instituto_previdencia_assistencia_social_2017, 'Receita', 'Código')
df_instituto_previdencia_assistencia_social_2017 = df_instituto_previdencia_assistencia_social_2017.reindex(columns=columns_Titles)
df_instituto_previdencia_assistencia_social_2017['Valor Previsto'] = df_instituto_previdencia_assistencia_social_2017['Valor Previsto'].apply(tratar_valores)
df_instituto_previdencia_assistencia_social_2017['Valor Arrecadado'] = df_instituto_previdencia_assistencia_social_2017['Valor Arrecadado'].apply(tratar_valores)
df_instituto_previdencia_assistencia_social_2017
# Out:
#       Número Guia      Código  \
# 0               1  1210290702
# 1               2  1210290702
# 2               3  1210290701
# 3               4  7210290200
# 4               5  7210290200
# ..            ...         ...
# 263           323  1328100000
# 264           324  1328100000
# 265           325  1328100000
# 266           326  1328100000
# 267           327  1328100000
#
#                                                Receita        Data  \
# 0    Contribuição de Servidor Ativo Civil - Prefeitura  31/01/2017
# 1    Contribuição de Servidor Ativo Civil - Prefeitura  31/01/2017
# 2        Contribuição de Servidor Ativo Civil - Câmara  27/01/2017
# 3    Contribuição Patronal - Câmara - Intra-Orçamen...  27/01/2017
# 4    Contribuição Patronal - Câmara - Intra-Orçamen...  30/01/2017
# ..                                                 ...         ...
# 263  Remuneração dos Investimentos do Regime Própri...  29/12/2017
# ...

# %%
tratar_df(df_prefeitura_2017, 'Receita', 'Código')
df_prefeitura_2017 = df_prefeitura_2017.reindex(columns=columns_Titles)
df_prefeitura_2017['Valor Previsto'] = df_prefeitura_2017['Valor Previsto'].apply(tratar_valores)
df_prefeitura_2017['Valor Arrecadado'] = df_prefeitura_2017['Valor Arrecadado'].apply(tratar_valores)
df_prefeitura_2017
# Out:
#        Número Guia      Código  \
# 0                1  1113050000
# 1                2  1113050000
# 2                3  1113050000
# 3                4  1113050000
# 4                5  1722010100
# ...            ...         ...
# 9442         27571  1112043100
# 9443         27572  1112043100
# 9444         27573  1112043100
# 9445         27574  1112043100
# 9446         27575  1112043100
#
#                                                 Receita        Data  \
# 0           Imposto sobre Serviços de Qualquer Natureza  02/01/2017
# 1           Imposto sobre Serviços de Qualquer Natureza  04/01/2017
# 2           Imposto sobre Serviços de Qualquer Natureza  05/01/2017
# 3           Imposto sobre Serviços de Qualquer Natureza  06/01/2017
# 4                                    Cota-Parte do ICMS  03/01/2017
# ...                                                 ...         ...
# 9442  Imposto de Renda Retido nas Fontes sobre os Re...  09/11/2017
# ...

# %%
tratar_df(df_sctrans_2017, 'Receita', 'Código')
df_sctrans_2017 = df_sctrans_2017.reindex(columns=columns_Titles)
df_sctrans_2017['Valor Previsto'] = df_sctrans_2017['Valor Previsto'].apply(tratar_valores)
df_sctrans_2017['Valor Arrecadado'] = df_sctrans_2017['Valor Arrecadado'].apply(tratar_valores)
df_sctrans_2017
# Out:
#       Número Guia      Código  \
# 0               1  1919150000
# 1               2  1919150000
# 2               3  1919150000
# 3               4  1919150000
# 4               5  1919150000
# ..            ...         ...
# 472           479  1919150000
# 473           480  1121300000
# 474           481  1919150000
# 475           482  1121300000
# 476           483  1325029900
#
#                                                Receita        Data  \
# 0           Multas Previstas na Legislação de Trânsito  02/01/2017
# 1           Multas Previstas na Legislação de Trânsito  03/01/2017
# 2           Multas Previstas na Legislação de Trânsito  05/01/2017
# 3           Multas Previstas na Legislação de Trânsito  11/01/2017
# 4           Multas Previstas na Legislação de Trânsito  12/01/2017
# ..                                                 ...         ...
# 472         Multas Previstas na Legislação de Trânsito  27/12/2017
# ...

# %% [markdown]
# ## Salvando dados tratados

# %%
df_instituto_previdencia_assistencia_social_2017.to_csv('03_dados_tratados/dados_assistencia_social_tratados_2017.csv', index=False, sep=';')
df_prefeitura_2017.to_csv('03_dados_tratados/dados_prefeitura_tratados_2017.csv', index=False, sep=';')
df_sctrans_2017.to_csv('03_dados_tratados/dados_sctrans_tratados_2017.csv.csv', index=False, sep=';')

# %% [markdown]
# ## Juntando todos os dados tratados em um único documento

# %%
df_prefeitura_2017['Tipo'] = 1
df_instituto_previdencia_assistencia_social_2017['Tipo'] = 2
df_sctrans_2017['Tipo'] = 3

# %%
df_dados_acumulados_2017 = pd.merge(df_prefeitura_2017, df_instituto_previdencia_assistencia_social_2017, how='outer')
df_dados_acumulados_2017 = pd.merge(df_dados_acumulados_2017, df_sctrans_2017, how='outer')
df_dados_acumulados_2017
# Out:
#         Número Guia      Código  \
# 0                 1  1113050000
# 1                 2  1113050000
# 2                 3  1113050000
# 3                 4  1113050000
# 4                 5  1722010100
# ...             ...         ...
# 10187           479  1919150000
# 10188           480  1121300000
# 10189           481  1919150000
# 10190           482  1121300000
# 10191           483  1325029900
#
#                                                  Receita        Data  \
# 0            Imposto sobre Serviços de Qualquer Natureza  02/01/2017
# 1            Imposto sobre Serviços de Qualquer Natureza  04/01/2017
# 2            Imposto sobre Serviços de Qualquer Natureza  05/01/2017
# 3            Imposto sobre Serviços de Qualquer Natureza  06/01/2017
# 4                                     Cota-Parte do ICMS  03/01/2017
# ...                                                  ...         ...
# 10187         Multas Previstas na Legislação de Trânsito  27/12/2017
# ...

# %%
df_dados_acumulados_2017.drop(' Número Guia',axis=1, inplace=True)
df_dados_acumulados_2017.drop('Valor Lançado',axis=1, inplace=True)
df_dados_acumulados_2017
# Out:
#            Código                                            Receita  \
# 0      1113050000        Imposto sobre Serviços de Qualquer Natureza
# 1      1113050000        Imposto sobre Serviços de Qualquer Natureza
# 2      1113050000        Imposto sobre Serviços de Qualquer Natureza
# 3      1113050000        Imposto sobre Serviços de Qualquer Natureza
# 4      1722010100                                 Cota-Parte do ICMS
# ...           ...                                                ...
# 10187  1919150000         Multas Previstas na Legislação de Trânsito
# 10188  1121300000  Taxa de Autorização de Funcionamento de Transp...
# 10189  1919150000         Multas Previstas na Legislação de Trânsito
# 10190  1121300000  Taxa de Autorização de Funcionamento de Transp...
# 10191  1325029900  Remuneração de Outros Depósitos de Recursos nã...
#
#              Data                  Nome            CPF/CNPJ Valor Previsto  \
# ...

# %%
df_dados_acumulados_2017.to_csv('04_analise_tratamento_carga/dados_acumulados_2017.csv', index=False, sep=';')
