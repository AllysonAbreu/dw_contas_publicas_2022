# %% [markdown]
# # Import e tratamento dos dados

# %% [markdown]
# ## Import de dados

# %%
import pandas as pd
import chardet

# %%
with open("02_dados_pre_tratados/dados_camara_2018.csv", "rb") as f:
    result = chardet.detect(f.read())

df_camara_2018 = pd.read_csv("02_dados_pre_tratados/dados_camara_2018.csv", sep=";", encoding=result['encoding'])
df_camara_2018
# Out:
#     Despesa  Número        Data                                Nome  \
# 0        11       1  28/02/2018  PREFEITURA MUNICIPAL DE CAJAZEIRAS
# 1         8       2  28/02/2018      Câmara Municipal de Cajazeiras
# 2        12       3  28/02/2018  PREFEITURA MUNICIPAL DE CAJAZEIRAS
# 3        18       4  28/02/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 4        21       5  28/02/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# ..      ...     ...         ...                                 ...
# 67       24      68  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 68       26      69  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 69       28      70  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 70     1438      71  31/12/2018  PREFEITURA MUNICIPAL DE CAJAZEIRAS
# 71       23      72  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
#
#               CPF/CNPJ Empenhado(R$) Liquidado(R$)    Pago(R$)  Saldo(R$)
# 0   08.923.971/0001-15           487           487         487          0
# ...

# %%
df_instituto_previdencia_2018 = pd.read_csv("02_dados_pre_tratados/dados_instituto_previdencia_2018.csv", sep=";", encoding=result['encoding'])
df_instituto_previdencia_2018
# Out:
#      Despesa  Número        Data  \
# 0        131       1  02/01/2018
# 1        131       2  02/01/2018
# 2        131       4  02/01/2018
# 3        131       5  03/01/2018
# 4        131       6  03/01/2018
# ..       ...     ...         ...
# 435      142     459  28/12/2018
# 436      142     460  28/12/2018
# 437      131     461  28/12/2018
# 438      123     462  31/12/2018
# 439      123     463  31/12/2018
#
#                                                   Nome            CPF/CNPJ  \
# 0                              CAIXA ECONOMICA FEDERAL  00.360.305/0040-10
# 1                              CAIXA ECONOMICA FEDERAL  00.360.305/0040-10
# 2                                   BANCO DO BRASIL SA  00.000.000/1641-19
# 3                        FRANCISCO LUCIANO DE OLIVEIRA  09.238.207/0001-73
# 4          ADLLINK PROVEDOR DE INTERNET VIA RADIO LTDA  05.748.217/0001-06
# ..                                                 ...                 ...
# ...

# %%
df_prefeitura_2018 = pd.read_csv("02_dados_pre_tratados/dados_prefeitura_2018.csv", sep=";", encoding=result['encoding'])
df_prefeitura_2018
# Out:
#       Despesa  Número        Data  \
# 0         932      24  02/01/2018
# 1         932      27  02/01/2018
# 2         932      30  02/01/2018
# 3         932      31  02/01/2018
# 4        1000      32  02/01/2018
# ...       ...     ...         ...
# 7751      722    7725  17/12/2018
# 7752      722    7762  24/12/2018
# 7753      717    7778  24/12/2018
# 7754      717    7789  24/12/2018
# 7755      722    7872  26/12/2018
#
#                                                Nome            CPF/CNPJ  \
# 0                       ROBENILSON FIRMINO DA SILVA      024.894.844-00
# 1                       ROBENILSON FIRMINO DA SILVA      024.894.844-00
# 2                       ROBENILSON FIRMINO DA SILVA      024.894.844-00
# 3                JUCELIO COSTA DE ARAUJO E CIA LTDA  04.709.948/0001-71
# 4                       ROBENILSON FIRMINO DA SILVA      024.894.844-00
# ...                                             ...                 ...
# ...

# %%
df_sctrans_2018 = pd.read_csv("02_dados_pre_tratados/dados_sctrans_2018.csv", sep=";", encoding=result['encoding'])
df_sctrans_2018
# Out:
#      Despesa  Número        Data  \
# 0         71       1  02/01/2018
# 1         72       2  02/01/2018
# 2         67       3  05/01/2018
# 3         67       4  05/01/2018
# 4         67       5  05/01/2018
# ..       ...     ...         ...
# 754       71     770  28/12/2018
# 755       72     771  28/12/2018
# 756       72     772  31/12/2018
# 757       59     773  31/12/2018
# 758       72     774  31/12/2018
#
#                                                   Nome            CPF/CNPJ  \
# 0                                   JOSE ARAUJO SANTOS      025.396.464-41
# 1    FIUZA CORDEIRO CONSULTORIA AUDITORIA E ASSESSO...  11.516.881/0001-14
# 2             DICAL - DISTRIB.DE VEICULOS CAJAZEIRAS L  35.503.721/0001-07
# 3             MARTINS COM.DE COMBUSTIVEIS E SERVIOS L  05.793.770/0001-52
# 4             MARTINS COM.DE COMBUSTIVEIS E SERVIOS L  05.793.770/0001-52
# ..                                                 ...                 ...
# ...

# %% [markdown]
# ## Tratamento dos DataFrames

# %%
# Definindo tipos das colunas antes de ler o dataset
columns_types = {'Empenhado(R$)':float,
                'Liquidado(R$)':float,
                'Pago(R$)':float,
                'Saldo(R$)':float}

# %%
'''
Função para tratamento dos valores monetários

'''

def tratar_valores(valor):
    
    '''
        Primeiramente, procura-se a localização do ponto, que separava os milhares, e a vírgula que definia os centavos de reais.
    '''
    posicao_virgula = valor.find(',')
    posicao_ponto = valor.find('.') 
    
    '''
        Após o armazenamento das posições de cada separador, armazenava o valor em uma nova string, sem os pontos e vírgulas, 
        e encontrava a nova posição do separador, agora um ponto.
    '''
    string = ''.join(filter(str.isalnum, valor))
    nova_posicao_ponto = posicao_virgula - (len(valor) - len(string))

    '''
        Por fim, após verificar qual condição a nova string se encaixava, retornava-se a nova string com o devido tratamento.
    '''
    if len(string) == len(valor):
        return valor
    
    elif posicao_ponto != -1:        
        string = string[0:nova_posicao_ponto+1] + '.' + string[nova_posicao_ponto+1:]
        return string
    
    else:
        string = string[0:posicao_virgula] + '.' + string[posicao_virgula:]
        return string

# %% [markdown]
# ### Tratando dados

# %%
df_camara_2018['Empenhado(R$)'] = df_camara_2018['Empenhado(R$)'].apply(tratar_valores)
df_camara_2018['Pago(R$)'] = df_camara_2018['Pago(R$)'].apply(tratar_valores)
df_camara_2018['Liquidado(R$)'] = df_camara_2018['Liquidado(R$)'].apply(tratar_valores)
df_camara_2018['Saldo(R$)'] = df_camara_2018['Saldo(R$)'].astype('object')

df_camara_2018
# Out:
#     Despesa  Número        Data                                Nome  \
# 0        11       1  28/02/2018  PREFEITURA MUNICIPAL DE CAJAZEIRAS
# 1         8       2  28/02/2018      Câmara Municipal de Cajazeiras
# 2        12       3  28/02/2018  PREFEITURA MUNICIPAL DE CAJAZEIRAS
# 3        18       4  28/02/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 4        21       5  28/02/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# ..      ...     ...         ...                                 ...
# 67       24      68  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 68       26      69  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 69       28      70  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 70     1438      71  31/12/2018  PREFEITURA MUNICIPAL DE CAJAZEIRAS
# 71       23      72  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
#
#               CPF/CNPJ Empenhado(R$) Liquidado(R$)   Pago(R$) Saldo(R$)
# 0   08.923.971/0001-15           487           487        487         0
# ...

# %%
df_instituto_previdencia_2018['Empenhado(R$)'] = df_instituto_previdencia_2018['Empenhado(R$)'].apply(tratar_valores)
df_instituto_previdencia_2018['Pago(R$)'] = df_instituto_previdencia_2018['Pago(R$)'].apply(tratar_valores)
df_instituto_previdencia_2018['Liquidado(R$)'] = df_instituto_previdencia_2018['Liquidado(R$)'].apply(tratar_valores)
df_instituto_previdencia_2018['Saldo(R$)'] = df_instituto_previdencia_2018['Saldo(R$)'].apply(tratar_valores)

df_instituto_previdencia_2018
# Out:
#      Despesa  Número        Data  \
# 0        131       1  02/01/2018
# 1        131       2  02/01/2018
# 2        131       4  02/01/2018
# 3        131       5  03/01/2018
# 4        131       6  03/01/2018
# ..       ...     ...         ...
# 435      142     459  28/12/2018
# 436      142     460  28/12/2018
# 437      131     461  28/12/2018
# 438      123     462  31/12/2018
# 439      123     463  31/12/2018
#
#                                                   Nome            CPF/CNPJ  \
# 0                              CAIXA ECONOMICA FEDERAL  00.360.305/0040-10
# 1                              CAIXA ECONOMICA FEDERAL  00.360.305/0040-10
# 2                                   BANCO DO BRASIL SA  00.000.000/1641-19
# 3                        FRANCISCO LUCIANO DE OLIVEIRA  09.238.207/0001-73
# 4          ADLLINK PROVEDOR DE INTERNET VIA RADIO LTDA  05.748.217/0001-06
# ..                                                 ...                 ...
# ...

# %%
df_prefeitura_2018['Empenhado(R$)'] = df_prefeitura_2018['Empenhado(R$)'].apply(tratar_valores)
df_prefeitura_2018['Pago(R$)'] = df_prefeitura_2018['Pago(R$)'].apply(tratar_valores)
df_prefeitura_2018['Liquidado(R$)'] = df_prefeitura_2018['Liquidado(R$)'].apply(tratar_valores)
df_prefeitura_2018['Saldo(R$)'] = df_prefeitura_2018['Saldo(R$)'].apply(tratar_valores)

df_prefeitura_2018
# Out:
#       Despesa  Número        Data  \
# 0         932      24  02/01/2018
# 1         932      27  02/01/2018
# 2         932      30  02/01/2018
# 3         932      31  02/01/2018
# 4        1000      32  02/01/2018
# ...       ...     ...         ...
# 7751      722    7725  17/12/2018
# 7752      722    7762  24/12/2018
# 7753      717    7778  24/12/2018
# 7754      717    7789  24/12/2018
# 7755      722    7872  26/12/2018
#
#                                                Nome            CPF/CNPJ  \
# 0                       ROBENILSON FIRMINO DA SILVA      024.894.844-00
# 1                       ROBENILSON FIRMINO DA SILVA      024.894.844-00
# 2                       ROBENILSON FIRMINO DA SILVA      024.894.844-00
# 3                JUCELIO COSTA DE ARAUJO E CIA LTDA  04.709.948/0001-71
# 4                       ROBENILSON FIRMINO DA SILVA      024.894.844-00
# ...                                             ...                 ...
# ...

# %%
df_sctrans_2018['Empenhado(R$)'] = df_sctrans_2018['Empenhado(R$)'].apply(tratar_valores)
df_sctrans_2018['Pago(R$)'] = df_sctrans_2018['Pago(R$)'].apply(tratar_valores)
df_sctrans_2018['Liquidado(R$)'] = df_sctrans_2018['Liquidado(R$)'].apply(tratar_valores)
df_sctrans_2018['Saldo(R$)'] = df_sctrans_2018['Saldo(R$)'].apply(tratar_valores)

df_sctrans_2018
# Out:
#      Despesa  Número        Data  \
# 0         71       1  02/01/2018
# 1         72       2  02/01/2018
# 2         67       3  05/01/2018
# 3         67       4  05/01/2018
# 4         67       5  05/01/2018
# ..       ...     ...         ...
# 754       71     770  28/12/2018
# 755       72     771  28/12/2018
# 756       72     772  31/12/2018
# 757       59     773  31/12/2018
# 758       72     774  31/12/2018
#
#                                                   Nome            CPF/CNPJ  \
# 0                                   JOSE ARAUJO SANTOS      025.396.464-41
# 1    FIUZA CORDEIRO CONSULTORIA AUDITORIA E ASSESSO...  11.516.881/0001-14
# 2             DICAL - DISTRIB.DE VEICULOS CAJAZEIRAS L  35.503.721/0001-07
# 3             MARTINS COM.DE COMBUSTIVEIS E SERVIOS L  05.793.770/0001-52
# 4             MARTINS COM.DE COMBUSTIVEIS E SERVIOS L  05.793.770/0001-52
# ..                                                 ...                 ...
# ...

# %% [markdown]
# ## Salvando dados tratados

# %%
df_instituto_previdencia_2018.to_csv('03_dados_tratados/dados_instituto_previdencia_2018_tratados.csv', index=False, sep=';')
df_prefeitura_2018.to_csv('03_dados_tratados/dados_prefeitura_2018_tratados.csv', index=False, sep=';')
df_sctrans_2018.to_csv('03_dados_tratados/dados_sctrans_2018_tratados.csv', index=False, sep=';')
df_camara_2018.to_csv('03_dados_tratados/dados_camara_2018_tratados.csv', index=False, sep=';')

# %% [markdown]
# ## Analisando dados contidos nos dataframes

# %%
df_prefeitura_2018['Tipo'] = 1
df_instituto_previdencia_2018['Tipo'] = 2
df_sctrans_2018['Tipo'] = 3
df_camara_2018['Tipo'] = 4

# %%
df_dados_acumulados_2018 = pd.merge(df_prefeitura_2018, df_instituto_previdencia_2018, how='outer')
df_dados_acumulados_2018 = pd.merge(df_dados_acumulados_2018, df_sctrans_2018, how='outer')
df_dados_acumulados_2018 = pd.merge(df_dados_acumulados_2018, df_camara_2018, how='outer')
df_dados_acumulados_2018
# Out:
#       Despesa  Número        Data                                Nome  \
# 0         932      24  02/01/2018         ROBENILSON FIRMINO DA SILVA
# 1         932      27  02/01/2018         ROBENILSON FIRMINO DA SILVA
# 2         932      30  02/01/2018         ROBENILSON FIRMINO DA SILVA
# 3         932      31  02/01/2018  JUCELIO COSTA DE ARAUJO E CIA LTDA
# 4        1000      32  02/01/2018         ROBENILSON FIRMINO DA SILVA
# ...       ...     ...         ...                                 ...
# 9022       24      68  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 9023       26      69  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 9024       28      70  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 9025     1438      71  31/12/2018  PREFEITURA MUNICIPAL DE CAJAZEIRAS
# 9026       23      72  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
#
#                 CPF/CNPJ Empenhado(R$) Liquidado(R$)   Pago(R$) Saldo(R$)  \
# ...

# %%
df_dados_acumulados_2018.drop('Despesa',axis=1, inplace=True)
df_dados_acumulados_2018
# Out:
#       Número        Data                                Nome  \
# 0         24  02/01/2018         ROBENILSON FIRMINO DA SILVA
# 1         27  02/01/2018         ROBENILSON FIRMINO DA SILVA
# 2         30  02/01/2018         ROBENILSON FIRMINO DA SILVA
# 3         31  02/01/2018  JUCELIO COSTA DE ARAUJO E CIA LTDA
# 4         32  02/01/2018         ROBENILSON FIRMINO DA SILVA
# ...      ...         ...                                 ...
# 9022      68  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 9023      69  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 9024      70  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
# 9025      71  31/12/2018  PREFEITURA MUNICIPAL DE CAJAZEIRAS
# 9026      72  31/12/2018      CAMARA MUNICIPAL DE CAJAZEIRAS
#
#                 CPF/CNPJ Empenhado(R$) Liquidado(R$)   Pago(R$) Saldo(R$)  \
# 0         024.894.844-00       3000.00       3000.00    3000.00         0
# 1         024.894.844-00       3000.00       3000.00    3000.00         0
# ...

# %%
df_dados_acumulados_2018.to_csv('04_analise_tratamento_carga/dados_acumulados_2018.csv', index=False, sep=';')
