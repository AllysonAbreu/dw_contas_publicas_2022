# %% [markdown]
# # Import e tratamento dos dados

# %% [markdown]
# ## Import de dados

# %%
import pandas as pd
import chardet

# %%
with open("02_dados_pre_tratados/dados_camara_2016.csv", "rb") as f:
    result = chardet.detect(f.read())

df_camara_2016 = pd.read_csv("02_dados_pre_tratados/dados_camara_2016.csv", sep=";", encoding=result['encoding'])
df_camara_2016
# Out:
#      Despesa  Número        Data                            Nome  \
# 0          8       1  29/01/2016  Câmara Municipal de Cajazeiras
# 1         11       2  29/01/2016                   Marcos Helder
# 2         13       3  29/01/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# 3         16       4  29/01/2016                   Marcos Helder
# 4         17       5  29/01/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# ..       ...     ...         ...                             ...
# 113       16     115  30/12/2016                   Marcos Helder
# 114       17     116  30/12/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# 115       22     117  30/12/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# 116       24     118  30/12/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# 117       25     119  30/12/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
#
#                CPF/CNPJ Empenhado(R$) Liquidado(R$)    Pago(R$)  Saldo(R$)
# 0    08.841.553/0001-89    198.773,28    198.773,28  198.773,28          0
# ...

# %%
df_instituto_previdencia_2016 = pd.read_csv("02_dados_pre_tratados/dados_instituto_previdencia_2016.csv", sep=";", encoding=result['encoding'])
df_instituto_previdencia_2016
# Out:
#      Despesa  Número        Data  \
# 0        126       1  04/01/2016
# 1        132       2  04/01/2016
# 2        129       3  04/01/2016
# 3        132       4  04/01/2016
# 4        132       5  04/01/2016
# ..       ...     ...         ...
# 489      130     496  27/12/2016
# 490      130     497  29/12/2016
# 491      137     501  30/12/2016
# 492      137     502  30/12/2016
# 493      138     503  30/12/2016
#
#                                                   Nome            CPF/CNPJ  \
# 0                    ANA BEATRIZ DIAS DE OLIVEIRA - ME  04.624.228/0001-03
# 1                        REGINALDO SOARES MOREIRA - ME  17.852.505/0001-87
# 2                                LORENA SOARES LACERDA      062.843.174-09
# 3                              TELEMAR NORTE LESTE S/A  33.000.118/0012-21
# 4                                      TIM CELULAR S/A  01.009.686/0080-48
# ..                                                 ...                 ...
# ...

# %%
df_prefeitura_2016 = pd.read_csv("02_dados_pre_tratados/dados_prefeitura_2016.csv", sep=";", encoding=result['encoding'])
df_prefeitura_2016
# Out:
#       Despesa  Número        Data                                     Nome  \
# 0         958       3  04/01/2016  CAGEPA-COM DE AGUA E ESGOTOS DA PARAIBA
# 1         961       4  04/01/2016        TELEMAR NORTE LESTE S.A.(OI FIXO)
# 2         901       5  04/01/2016            BRUNO NATHANAEL LOPES BARRETO
# 3        1173       6  04/01/2016            BRUNO NATHANAEL LOPES BARRETO
# 4         961      26  04/01/2016        TELEMAR NORTE LESTE S.A.(OI FIXO)
# ...       ...     ...         ...                                      ...
# 7510      615    7242  14/12/2016              MINISTERIO DO MEIO AMBIENTE
# 7511      607    7254  15/12/2016       MARIA DE FATIMA CARTAXO E CIA LTDA
# 7512      602    7323  22/12/2016       Prefeitura Municipal de Cajazeiras
# 7513      602    7440  27/12/2016       Prefeitura Municipal de Cajazeiras
# 7514      607    7491  27/12/2016       MARIA DE FATIMA CARTAXO E CIA LTDA
#
# ...

# %%
df_sctrans_2016 = pd.read_csv("02_dados_pre_tratados/dados_sctrans_2016.csv", sep=";", encoding=result['encoding'])
df_sctrans_2016
# Out:
#      Despesa  Número        Data                                        Nome  \
# 0         70       1  04/01/2016                 JESSICA LIMA DAMASCENA - ME
# 1         63       2  04/01/2016                      SANDRO DIAS DE FREITAS
# 2         68       3  04/01/2016            JISNELY FEITOSA NOGUEIRA SERVULO
# 3         68       4  04/01/2016            FRANCISCO JOSE ALEXANDRE MOREIRA
# 4         70       5  04/01/2016                       EDSON SIMÃO VERISSIMO
# ..       ...     ...         ...                                         ...
# 324       56     328  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
# 325       56     329  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
# 326       56     330  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
# 327       56     331  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
# 328       56     332  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
#
# ...

# %% [markdown]
# ## Tratamento dos DataFrames

# %%
# Definindo tipos das colunas antes de ler o dataset
columns_types = {'Empenhado(R$)':float,
                'Liquidado(R$)':float,
                'Pago(R$)':float,
                'Saldo(R$)':float}

# %%
'''
Função para tratamento dos valores monetários

'''

def tratar_valores(valor):
    
    '''
        Primeiramente, procura-se a localização do ponto, que separava os milhares, e a vírgula que definia os centavos de reais.
    '''
    posicao_virgula = valor.find(',')
    posicao_ponto = valor.find('.') 
    
    '''
        Após o armazenamento das posições de cada separador, armazenava o valor em uma nova string, sem os pontos e vírgulas, 
        e encontrava a nova posição do separador, agora um ponto.
    '''
    string = ''.join(filter(str.isalnum, valor))
    nova_posicao_ponto = posicao_virgula - (len(valor) - len(string))

    '''
        Por fim, após verificar qual condição a nova string se encaixava, retornava-se a nova string com o devido tratamento.
    '''
    if len(string) == len(valor):
        return valor
    
    elif posicao_ponto != -1:        
        string = string[0:nova_posicao_ponto+1] + '.' + string[nova_posicao_ponto+1:]
        return string
    
    else:
        string = string[0:posicao_virgula] + '.' + string[posicao_virgula:]
        return string

# %% [markdown]
# ### Tratando dados

# %%
df_camara_2016['Empenhado(R$)'] = df_camara_2016['Empenhado(R$)'].apply(tratar_valores)
df_camara_2016['Pago(R$)'] = df_camara_2016['Pago(R$)'].apply(tratar_valores)
df_camara_2016['Liquidado(R$)'] = df_camara_2016['Liquidado(R$)'].apply(tratar_valores)
df_camara_2016['Saldo(R$)'] = df_camara_2016['Saldo(R$)'].astype('object')

df_camara_2016
# Out:
#      Despesa  Número        Data                            Nome  \
# 0          8       1  29/01/2016  Câmara Municipal de Cajazeiras
# 1         11       2  29/01/2016                   Marcos Helder
# 2         13       3  29/01/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# 3         16       4  29/01/2016                   Marcos Helder
# 4         17       5  29/01/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# ..       ...     ...         ...                             ...
# 113       16     115  30/12/2016                   Marcos Helder
# 114       17     116  30/12/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# 115       22     117  30/12/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# 116       24     118  30/12/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
# 117       25     119  30/12/2016  CAMARA MUNICIPAL DE CAJAZEIRAS
#
#                CPF/CNPJ Empenhado(R$) Liquidado(R$)   Pago(R$) Saldo(R$)
# 0    08.841.553/0001-89     198773.28     198773.28  198773.28         0
# ...

# %%
df_instituto_previdencia_2016['Empenhado(R$)'] = df_instituto_previdencia_2016['Empenhado(R$)'].apply(tratar_valores)
df_instituto_previdencia_2016['Pago(R$)'] = df_instituto_previdencia_2016['Pago(R$)'].apply(tratar_valores)
df_instituto_previdencia_2016['Liquidado(R$)'] = df_instituto_previdencia_2016['Liquidado(R$)'].apply(tratar_valores)
df_instituto_previdencia_2016['Saldo(R$)'] = df_instituto_previdencia_2016['Saldo(R$)'].apply(tratar_valores)

df_instituto_previdencia_2016
# Out:
#      Despesa  Número        Data  \
# 0        126       1  04/01/2016
# 1        132       2  04/01/2016
# 2        129       3  04/01/2016
# 3        132       4  04/01/2016
# 4        132       5  04/01/2016
# ..       ...     ...         ...
# 489      130     496  27/12/2016
# 490      130     497  29/12/2016
# 491      137     501  30/12/2016
# 492      137     502  30/12/2016
# 493      138     503  30/12/2016
#
#                                                   Nome            CPF/CNPJ  \
# 0                    ANA BEATRIZ DIAS DE OLIVEIRA - ME  04.624.228/0001-03
# 1                        REGINALDO SOARES MOREIRA - ME  17.852.505/0001-87
# 2                                LORENA SOARES LACERDA      062.843.174-09
# 3                              TELEMAR NORTE LESTE S/A  33.000.118/0012-21
# 4                                      TIM CELULAR S/A  01.009.686/0080-48
# ..                                                 ...                 ...
# ...

# %%
df_prefeitura_2016['Empenhado(R$)'] = df_prefeitura_2016['Empenhado(R$)'].apply(tratar_valores)
df_prefeitura_2016['Pago(R$)'] = df_prefeitura_2016['Pago(R$)'].apply(tratar_valores)
df_prefeitura_2016['Liquidado(R$)'] = df_prefeitura_2016['Liquidado(R$)'].apply(tratar_valores)
df_prefeitura_2016['Saldo(R$)'] = df_prefeitura_2016['Saldo(R$)'].apply(tratar_valores)

df_prefeitura_2016
# Out:
#       Despesa  Número        Data                                     Nome  \
# 0         958       3  04/01/2016  CAGEPA-COM DE AGUA E ESGOTOS DA PARAIBA
# 1         961       4  04/01/2016        TELEMAR NORTE LESTE S.A.(OI FIXO)
# 2         901       5  04/01/2016            BRUNO NATHANAEL LOPES BARRETO
# 3        1173       6  04/01/2016            BRUNO NATHANAEL LOPES BARRETO
# 4         961      26  04/01/2016        TELEMAR NORTE LESTE S.A.(OI FIXO)
# ...       ...     ...         ...                                      ...
# 7510      615    7242  14/12/2016              MINISTERIO DO MEIO AMBIENTE
# 7511      607    7254  15/12/2016       MARIA DE FATIMA CARTAXO E CIA LTDA
# 7512      602    7323  22/12/2016       Prefeitura Municipal de Cajazeiras
# 7513      602    7440  27/12/2016       Prefeitura Municipal de Cajazeiras
# 7514      607    7491  27/12/2016       MARIA DE FATIMA CARTAXO E CIA LTDA
#
# ...

# %%
df_sctrans_2016['Empenhado(R$)'] = df_sctrans_2016['Empenhado(R$)'].apply(tratar_valores)
df_sctrans_2016['Pago(R$)'] = df_sctrans_2016['Pago(R$)'].apply(tratar_valores)
df_sctrans_2016['Liquidado(R$)'] = df_sctrans_2016['Liquidado(R$)'].apply(tratar_valores)
df_sctrans_2016['Saldo(R$)'] = df_sctrans_2016['Saldo(R$)'].apply(tratar_valores)

df_sctrans_2016
# Out:
#      Despesa  Número        Data                                        Nome  \
# 0         70       1  04/01/2016                 JESSICA LIMA DAMASCENA - ME
# 1         63       2  04/01/2016                      SANDRO DIAS DE FREITAS
# 2         68       3  04/01/2016            JISNELY FEITOSA NOGUEIRA SERVULO
# 3         68       4  04/01/2016            FRANCISCO JOSE ALEXANDRE MOREIRA
# 4         70       5  04/01/2016                       EDSON SIMÃO VERISSIMO
# ..       ...     ...         ...                                         ...
# 324       56     328  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
# 325       56     329  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
# 326       56     330  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
# 327       56     331  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
# 328       56     332  30/12/2016  INSS - INSTITUTO NACIONAL DO SEGURO SOCIAL
#
# ...

# %% [markdown]
# ## Salvando dados tratados

# %%
df_instituto_previdencia_2016.to_csv('03_dados_tratados/dados_instituto_previdencia_2016_tratados.csv', index=False, sep=';')
df_prefeitura_2016.to_csv('03_dados_tratados/dados_prefeitura_2016_tratados.csv', index=False, sep=';')
df_sctrans_2016.to_csv('03_dados_tratados/dados_sctrans_2016_tratados.csv', index=False, sep=';')
df_camara_2016.to_csv('03_dados_tratados/dados_camara_2016_tratados.csv', index=False, sep=';')

# %% [markdown]
# ## Analisando dados contidos nos dataframes

# %%
df_prefeitura_2016['Tipo'] = 1
df_instituto_previdencia_2016['Tipo'] = 2
df_sctrans_2016['Tipo'] = 3
df_camara_2016['Tipo'] = 4

# %%
df_dados_acumulados_2016 = pd.merge(df_prefeitura_2016, df_instituto_previdencia_2016, how='outer')
df_dados_acumulados_2016 = pd.merge(df_dados_acumulados_2016, df_sctrans_2016, how='outer')
df_dados_acumulados_2016 = pd.merge(df_dados_acumulados_2016, df_camara_2016, how='outer')
df_dados_acumulados_2016
# Out:
#       Despesa  Número        Data                                     Nome  \
# 0         958       3  04/01/2016  CAGEPA-COM DE AGUA E ESGOTOS DA PARAIBA
# 1         961       4  04/01/2016        TELEMAR NORTE LESTE S.A.(OI FIXO)
# 2         901       5  04/01/2016            BRUNO NATHANAEL LOPES BARRETO
# 3        1173       6  04/01/2016            BRUNO NATHANAEL LOPES BARRETO
# 4         961      26  04/01/2016        TELEMAR NORTE LESTE S.A.(OI FIXO)
# ...       ...     ...         ...                                      ...
# 8451       16     115  30/12/2016                            Marcos Helder
# 8452       17     116  30/12/2016           CAMARA MUNICIPAL DE CAJAZEIRAS
# 8453       22     117  30/12/2016           CAMARA MUNICIPAL DE CAJAZEIRAS
# 8454       24     118  30/12/2016           CAMARA MUNICIPAL DE CAJAZEIRAS
# 8455       25     119  30/12/2016           CAMARA MUNICIPAL DE CAJAZEIRAS
#
# ...

# %%
df_dados_acumulados_2016.drop('Despesa',axis=1, inplace=True)
df_dados_acumulados_2016
# Out:
#       Número        Data                                     Nome  \
# 0          3  04/01/2016  CAGEPA-COM DE AGUA E ESGOTOS DA PARAIBA
# 1          4  04/01/2016        TELEMAR NORTE LESTE S.A.(OI FIXO)
# 2          5  04/01/2016            BRUNO NATHANAEL LOPES BARRETO
# 3          6  04/01/2016            BRUNO NATHANAEL LOPES BARRETO
# 4         26  04/01/2016        TELEMAR NORTE LESTE S.A.(OI FIXO)
# ...      ...         ...                                      ...
# 8451     115  30/12/2016                            Marcos Helder
# 8452     116  30/12/2016           CAMARA MUNICIPAL DE CAJAZEIRAS
# 8453     117  30/12/2016           CAMARA MUNICIPAL DE CAJAZEIRAS
# 8454     118  30/12/2016           CAMARA MUNICIPAL DE CAJAZEIRAS
# 8455     119  30/12/2016           CAMARA MUNICIPAL DE CAJAZEIRAS
#
#                 CPF/CNPJ Empenhado(R$) Liquidado(R$)  Pago(R$) Saldo(R$)  Tipo
# 0     09.123.654/0001-87         81.12         81.12     81.12         0     1
# ...

# %%
df_dados_acumulados_2016.to_csv('04_analise_tratamento_carga/dados_acumulados_2016.csv', index=False, sep=';')
